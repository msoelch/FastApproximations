# %% [markdown]
# ## MNIST
# Utilizes code from crino module. Run notebook with --pylab switch.

# %%
import numpy as np
import theano
import gzip, cPickle
import crino
from theano.tensor.nnet.conv import conv2d as conv

# %%
# notebook specific imports
from lconvista import getMNIST, lconvista, sh_ksparse
import misc
import matplotlib
import matplotlib.pyplot as plt
from matplotlib import cm

# %%
# uncomment next two lines if inline plotting should be enabled.
# %matplotlib inline
matplotlib.rcParams['savefig.dpi'] = 144

# %%
data, dtrgts, valid, vtrgts, test, ttrgts, dm =  getMNIST(square=True)

file = "experiments\epochs99_layers10_k2_filters16_shape5_lambda1.000000_L5\sparse_epoch39.pkl.gz"  
f = gzip.open(file,'rb')                              
params = cPickle.load(f)                
f.close()
D = np.asarray(params[0])#,dtype=theano.config.floatX)
D180 = np.asarray(params[1])#,dtype=theano.config.floatX)
theta = np.asarray(params[2])#,dtype=theano.config.floatX)
L = np.asarray(params[3])#,dtype=theano.config.floatX)
layers = params[4]
n_filters = params[5]
filter_size = params[6]
k = params[7]

btsz = 100
zinit_shape = (btsz,n_filters,
               data[0,0].shape[0]+filter_size-1,
               data[0,0].shape[1]+filter_size-1)

config = {"D": D, "D180": D180, "theta": theta, "L": L, "Zinit": zinit_shape,
          "layers": layers, "Xshape": (btsz,1,28,28), "btsz": btsz, "k":k}


X, params, Z, rec, re, sparsity = lconvista(config,sh_ksparse)

extract = theano.function([X],Z)
reconstruction = theano.function([X],rec)
# Out:
# [LConvISTA]

# %%
im = np.array(misc.visualize(D,filter_size**2))
plt.imshow(im)#, cmap=cm.gray)

# %%
i = 80
rawbatch=data[i*btsz:(i+1)*btsz]
Z = extract(rawbatch)

print 'Nonzero entries:', 100*np.round(np.count_nonzero(Z) / float(Z.size),decimals=5), '%'
print 'Entries > theta:', 100*np.round(np.mean(np.abs(Z) > 0.2*theta), decimals=5), '%'
print theta
print Z.max(), Z.min()

Z1 = Z[10]
im = np.array(misc.visualize((abs(Z1) > 0.0*theta) * Z1, zinit_shape[2]**2))
plt.imshow(im)#, cmap=cm.gray)
# Out:
# Nonzero entries: 12.5 %
# Entries > theta: 2.507 %
# 0.40435029622
# 0.55978763216 -0.000123769048444

# %%
im = np.array(misc.visualize(rawbatch+dm, 28**2))
plt.imshow(im, cmap=cm.gray)

# %%
r = reconstruction(rawbatch)
im = np.array(misc.visualize(r+dm, 28**2))
plt.imshow(im, cmap=cm.gray)

# %%
im = np.array(misc.visualize((r-rawbatch)**2, 28**2))
plt.imshow(im, cmap=cm.gray)

# %%
plt.hist(Z.flatten(),1000)
# Out:
# (array([  1.73654200e+06,   4.38800000e+03,   3.77600000e+03,
#           3.34400000e+03,   2.99800000e+03,   2.73100000e+03,
#           2.42900000e+03,   2.19500000e+03,   2.08300000e+03,
#           1.81800000e+03,   1.77500000e+03,   1.57000000e+03,
#           1.50900000e+03,   1.46400000e+03,   1.32300000e+03,
#           1.26900000e+03,   1.26400000e+03,   1.19400000e+03,
#           1.10600000e+03,   1.11300000e+03,   1.01700000e+03,
#           9.67000000e+02,   9.19000000e+02,   8.60000000e+02,
#           8.57000000e+02,   8.76000000e+02,   8.05000000e+02,
#           7.86000000e+02,   8.07000000e+02,   6.96000000e+02,
#           6.71000000e+02,   6.59000000e+02,   6.84000000e+02,
#           6.06000000e+02,   6.77000000e+02,   6.46000000e+02,
#           5.68000000e+02,   5.58000000e+02,   5.51000000e+02,
#           5.11000000e+02,   5.73000000e+02,   5.06000000e+02,
#           4.90000000e+02,   4.84000000e+02,   4.43000000e+02,
# ...
