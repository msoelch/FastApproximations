# %% [markdown]
# ## MNIST
# Utilizes code from crino module. Run notebook with --pylab switch.

# %%
import numpy as np
import theano
import gzip, cPickle
import crino

# %%
# notebook specific imports
from lconvista import getMNIST, lconvista, sh_ksparse
import misc
import matplotlib
import matplotlib.pyplot as plt
from matplotlib import cm

# %%
# uncomment next two lines if inline plotting should be enabled.
# %matplotlib inline
matplotlib.rcParams['savefig.dpi'] = 144

# %%
data, dtrgts, valid, vtrgts, test, ttrgts, dm =  getMNIST(square=True)

file = "experiments\epochs99_layers10_k11_filters16_shape7_lambda2.000000_L5_test\sparse_epoch3.pkl.gz" 
f = gzip.open(file,'rb')                              
params = cPickle.load(f)                
f.close()
D = np.asarray(params[0])#,dtype=theano.config.floatX)
D180 = np.asarray(params[1])#,dtype=theano.config.floatX)
theta = np.asarray(params[2])#,dtype=theano.config.floatX)
L = np.asarray(params[3])#,dtype=theano.config.floatX)
layers = params[4]
n_filters = params[5]
filter_size = params[6]
k = params[7]
axes = params[8]

btsz = 100
zinit_shape = (btsz,n_filters,
               data[0,0].shape[0]+filter_size-1,
               data[0,0].shape[1]+filter_size-1)

config = {"D": D, "D180": D180, "theta": theta, "L": L, "Zshape": zinit_shape,
          "layers": layers, "Xshape": (btsz,1,28,28), "btsz": btsz, "k":k,"axes":axes}


X, params, Z, rec, re, sparsity = lconvista(config)

extract = theano.function([X],Z)
reconstruction = theano.function([X],rec)
# Out:
# [LConvISTA]

# %%
im = np.array(misc.visualize(D,filter_size**2))
plt.imshow(im, cmap=cm.gray)
(D**2).sum(axis=-1).sum(axis=-1)
# Out:
# array([[ 1.        ,  1.        ,  1.        ,  1.        ,  1.00000012,
#          1.        ,  1.00000012,  0.99999994,  1.        ,  1.        ,
#          1.        ,  1.        ,  1.        ,  1.        ,  1.00000012,
#          1.        ]], dtype=float32)

# %%
i = 1
rawbatch=data[i*btsz:(i+1)*btsz]
Z = extract(rawbatch)

print 'Nonzero entries:', 100*np.round(np.count_nonzero(Z) / float(Z.size),decimals=5), '%'
print 'Entries > theta:', 100*np.round(np.mean(np.abs(Z) > 0.5*theta), decimals=5), '%'
print theta
print Z.max(), Z.min()
print Z.mean(), Z.var()

Z1 = Z[10]
im = np.array(misc.visualize((abs(Z1) > 0.0*theta) * Z1, zinit_shape[2]**2))
plt.imshow(im)#, cmap=cm.gray)
# Out:
# Nonzero entries: 0.952 %
# Entries > theta: 0.595 %
# 0.409010082483
# 0.983997467043 0.0
# 0.0024736429897 0.000796221648571

# %%
im = np.array(misc.visualize(rawbatch+dm, 28**2))
plt.imshow(im, cmap=cm.gray)
print dtrgts[i*btsz:(i+1)*btsz].reshape(10,10)
# Out:
# [[5 7 1 7 1 1 6 3 0 2]
#  [9 3 1 1 0 4 9 2 0 0]
#  [2 0 2 7 1 8 6 4 1 6]
#  [3 4 5 9 1 3 3 8 5 4]
#  [7 7 4 2 8 5 8 6 7 3]
#  [4 6 1 9 9 6 0 3 7 2]
#  [8 2 9 4 4 6 4 9 7 0]
#  [9 2 9 5 1 5 9 1 2 3]
#  [2 3 5 9 1 7 6 2 8 2]
#  [2 5 0 7 4 9 7 8 3 2]]

# %%
r = reconstruction(rawbatch+dm)
im = np.array(misc.visualize(r, 28**2))
plt.imshow(im, cmap=cm.gray)

# %%
im = np.array(misc.visualize((r-rawbatch)**1, 28**2))
plt.imshow(im, cmap=cm.gray)
